# %% [markdown]
# ## Compare the Multi-class Classification Performance in Complete vs N Packet Flows Settings

# %%
MODEL = "rf"

# %%
import os
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd
import numpy as np
import warnings

def process_dataframes(dfs, n_values, day):    
    warnings.filterwarnings("ignore")  # Ignore warnings for cleaner output

    # Define table formatting
    header = ["DS", "TOTAL", "BENIGN", "ANOMALY", "Anomaly breakdown", "Min Dur.", "Mean Dur.", "Max Dur."]
    rowh = "{:^12} " * 4 + "{:^26} " + "{:^10} " + "{:^12} " + "{:^12} "
    row  = "{:^12} " * 4 + "{:<18}  " + "{:>6} " + "{:>10} " + "{:>12} " + "{:>12} "
    sep  = ["-"*12] * 4 + ["-"*26] + ["-"*10] + ["-"*12] + ["-"*12]

    # Print header
    print(rowh.format(*header))

    # Process each DataFrame
    for n, csv in zip(n_values, dfs):
        print(rowh.format(*sep))  # Separator line

        # Compute statistics
        TOTAL = len(csv)
        BENIGN = len(csv[csv["label"] == "BENIGN"])
        ANOMALY = len(csv[(csv["label"] != "BENIGN")])

        # Print the DataFrame summary
        print(row.format(day + '_' + str(n), TOTAL, BENIGN, ANOMALY, "", "", "", "", ""))

        # Iterate through each unique label
        for label in sorted(csv["label"].unique().tolist()):
            if label in ["BENIGN"]:
                continue  # Skip benign and NaN labels

            # Calculate duration statistics for each anomaly
            anomaly_data = csv[csv["label"] == label]['bidirectional_duration_ms']
            min_duration = np.min(anomaly_data) if not anomaly_data.empty else 0
            mean_duration = np.mean(anomaly_data) if not anomaly_data.empty else 0
            max_duration = np.max(anomaly_data) if not anomaly_data.empty else 0
            
            # Print anomaly statistics
            print(row.format("", "", "", "", label, len(csv[csv["label"] == label]), min_duration, "{:.2f}".format(mean_duration), max_duration))


# Function to evaluate model, store metrics, and return confusion matrix for plotting
def evaluate_and_store_results(y_true, y_pred, dataset_name):
    # Compute both non-normalized and normalized confusion matrices
    cm = confusion_matrix(y_true, y_pred)
    cm_normalized = confusion_matrix(y_true, y_pred, normalize='true')

    # Calculate individual metrics for multi-class classification
    # precision = precision_score(y_true, y_pred, average=None)  # Returns score for each class
    # recall = recall_score(y_true, y_pred, average=None)
    # f1 = f1_score(y_true, y_pred, average=None)
    
    # Calculate average metrics for overall evaluation
    precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
    recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
    
    metrics = {
        'Accuracy': accuracy_score(y_true, y_pred),
        'Balanced Accuracy': balanced_accuracy_score(y_true, y_pred),
        # 'Precision': precision.tolist(),  # Convert numpy array to list for JSON compatibility
        # 'Recall': recall.tolist(),
        # 'F1 Score': f1.tolist(),
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1 Score': f1_macro,
        'Classification Report': classification_report(y_true, y_pred, output_dict=True, zero_division=0),
        'Confusion Matrix': cm.tolist(),  # Store the non-normalized confusion matrix
        'Normalized Confusion Matrix': cm_normalized.tolist()  # Store the normalized confusion matrix
    }
    
    metrics_dict[dataset_name] = metrics  # Store metrics
    print(f"{dataset_name}") 
    print(f"Accuracy: {metrics['Accuracy']:.4f}, Balanced Accuracy: {metrics['Balanced Accuracy']:.4f}")
    # print(f"Precision (per class): {metrics['Precision']}")
    # print(f"Recall (per class): {metrics['Recall']}")
    # print(f"F1 Score (per class): {metrics['F1 Score']}")
    print(f"Macro Precision: {metrics['Macro Precision']:.4f}, Macro Recall: {metrics['Macro Recall']:.4f}, Macro F1 Score: {metrics['Macro F1 Score']:.4f}")
    print(f"Classification Report:\n{classification_report(y_true, y_pred)}\n")
    return cm_normalized  # Return normalized matrix for plotting

# Set global default font size for all plots
plt.rcParams.update({'font.size': 14})

# Define the columns to keep
columns_to_keep = [
    "protocol", 
    "bidirectional_duration_ms", "bidirectional_packets", "bidirectional_bytes",
    "src2dst_duration_ms", "src2dst_packets", "src2dst_bytes",
    "dst2src_duration_ms", "dst2src_packets",  "dst2src_bytes",
    "bidirectional_min_ps", "bidirectional_mean_ps", "bidirectional_stddev_ps", "bidirectional_max_ps", 
    "src2dst_min_ps", "src2dst_mean_ps", "src2dst_stddev_ps", "src2dst_max_ps",
    "dst2src_min_ps", "dst2src_mean_ps", "dst2src_stddev_ps", "dst2src_max_ps",
    "bidirectional_min_piat_ms", "bidirectional_mean_piat_ms", "bidirectional_stddev_piat_ms", "bidirectional_max_piat_ms", 
    "src2dst_min_piat_ms", "src2dst_mean_piat_ms", "src2dst_stddev_piat_ms", "src2dst_max_piat_ms", 
    "dst2src_min_piat_ms", "dst2src_mean_piat_ms", "dst2src_stddev_piat_ms", "dst2src_max_piat_ms",
    "bidirectional_syn_packets", "bidirectional_cwr_packets", "bidirectional_ece_packets", "bidirectional_urg_packets",
    "bidirectional_ack_packets", "bidirectional_psh_packets", "bidirectional_rst_packets", "bidirectional_fin_packets",
    "src2dst_syn_packets", "src2dst_cwr_packets", "src2dst_ece_packets", "src2dst_urg_packets",
    "src2dst_ack_packets", "src2dst_psh_packets", "src2dst_rst_packets", "src2dst_fin_packets",
    "dst2src_syn_packets", "dst2src_cwr_packets", "dst2src_ece_packets", "dst2src_urg_packets",
    "dst2src_ack_packets", "dst2src_psh_packets", "dst2src_rst_packets", "dst2src_fin_packets",    
]

RESULTS_DIR = "results"
CSV_DIR = "datasets"
DAY = "wednesday"

CF = 'cf'
Ns = list(range(2, 18))

# Initialize a dictionary to store all metrics
all_metrics_dict = {}

# Load the constant cf dataframe
df1 = pd.read_parquet(os.path.join(CSV_DIR, f'wednesday_{CF}.parquet'))

# Main cycle
for n in Ns:
    # Load each N dataframe
    df2 = pd.read_parquet(os.path.join(CSV_DIR, f'wednesday_pc_{n}.parquet'))
    
    df1_filtered = df1[df1['flow_key_hash'].isin(df2['flow_key_hash'])][columns_to_keep + ['label', 'flow_key_hash']]
    df2_filtered = df2[df2['flow_key_hash'].isin(df1['flow_key_hash'])][columns_to_keep + ['label', 'flow_key_hash']]

    process_dataframes([df1_filtered, df2_filtered], [CF,n], DAY)
    
    # Train-test split based on 'forward_hash'
    _, test_hashes = train_test_split(df1_filtered['flow_key_hash'], test_size=0.25, random_state=42, stratify=df1_filtered['label'])
    train_mask_df1 = ~df1_filtered['flow_key_hash'].isin(test_hashes)
    test_mask_df1 = df1_filtered['flow_key_hash'].isin(test_hashes)
    train_mask_df2 = ~df2_filtered['flow_key_hash'].isin(test_hashes)
    test_mask_df2 = df2_filtered['flow_key_hash'].isin(test_hashes)
    
    # Preparing training and testing sets
    X_train_1, X_test_1 = df1_filtered[train_mask_df1][columns_to_keep], df1_filtered[test_mask_df1][columns_to_keep]
    y_train_1, y_test_1 = df1_filtered[train_mask_df1]['label'], df1_filtered[test_mask_df1]['label']
    X_train_2, X_test_2 = df2_filtered[train_mask_df2][columns_to_keep], df2_filtered[test_mask_df2][columns_to_keep]
    y_train_2, y_test_2 = df2_filtered[train_mask_df2]['label'], df2_filtered[test_mask_df2]['label']

    if MODEL == "dt":
        # Initialize and train Decision Tree classifiers
        clf1 = DecisionTreeClassifier(random_state=42).fit(X_train_1, y_train_1)
        clf2 = DecisionTreeClassifier(random_state=42).fit(X_train_2, y_train_2)
    if MODEL == "rf":
        # Initialize and train Random Forest classifier
        clf1 = RandomForestClassifier(random_state=42).fit(X_train_1, y_train_1)
        clf2 = RandomForestClassifier(random_state=42).fit(X_train_2, y_train_2)

    # Dictionary to store all metrics
    metrics_dict = {}

    # Evaluate and plot results
    titles = [f'{CF.upper()} Train, {CF.upper()} Test', f'N{n} Train, N{n} Test', f'{CF.upper()} Train, N{n} Test']
    predictions = [clf1.predict(X_test_1), clf2.predict(X_test_2), clf1.predict(X_test_2)]
    tests = [y_test_1, y_test_2, y_test_2]
    
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    for ax, title, y_test, y_pred in zip(axes.flat, titles, tests, predictions):
        cm = evaluate_and_store_results(y_test, y_pred, title)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y_test))
        disp.plot(cmap=plt.cm.Blues, ax=ax, colorbar=False, values_format='.2f')
        ax.title.set_text(title)
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    
    plt.tight_layout()
    plt.show()

    all_metrics_dict[f'PC{n}'] = metrics_dict  # Store the metrics for this round using N{n} as the key

# After the loop, write all_metrics_dict to a single JSON file
output_dir = RESULTS_DIR
os.makedirs(output_dir, exist_ok=True)  # Ensure output directory exists

file_name = f'{MODEL}_multi_{CF}_pcf_evaluation_metrics.json'  # Updated file name to reflect consolidated metrics
destination = os.path.join(output_dir, file_name)

with open(destination, 'w') as f:
    json.dump(all_metrics_dict, f, indent=4)
# Out:
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    500493       324508       175985
#                                                     DoS GoldenEye         7917          0     11028.96       106793
#                                                     DoS Hulk            158680          0       693.68       128843
#                                                     DoS Slowhttptest      3705          0      9568.14       167903
#                                                     DoS Slowloris         5683          0     33548.82       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_2     500493       324508       175985
#                                                     DoS GoldenEye         7917          0       130.35        58333
#                                                     DoS Hulk            158680          0       456.34        32096
#                                                     DoS Slowhttptest      3705          0       152.66        36864
#                                                     DoS Slowloris         5683          0       168.72         1000
# CF Train, CF Test
# Accuracy: 0.9995, Balanced Accuracy: 0.9904
# Macro Precision: 0.9963, Macro Recall: 0.9904, Macro F1 Score: 0.9932
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     81128
#    DoS GoldenEye       1.00      0.99      0.99      1979
#         DoS Hulk       1.00      1.00      1.00     39670
# DoS Slowhttptest       1.00      0.96      0.98       926
#    DoS Slowloris       0.99      1.00      0.99      1421
#
#         accuracy                           1.00    125124
#        macro avg       1.00      0.99      0.99    125124
#     weighted avg       1.00      1.00      1.00    125124
#
#
# N2 Train, N2 Test
# Accuracy: 0.9695, Balanced Accuracy: 0.6452
# Macro Precision: 0.9587, Macro Recall: 0.6452, Macro F1 Score: 0.7022
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      0.99      0.99     81128
#    DoS GoldenEye       0.91      0.04      0.07      1979
#         DoS Hulk       0.91      1.00      0.95     39670
# DoS Slowhttptest       0.99      0.57      0.73       926
#    DoS Slowloris       0.97      0.63      0.76      1421
#
#         accuracy                           0.97    125124
#        macro avg       0.96      0.65      0.70    125124
#     weighted avg       0.97      0.97      0.96    125124
#
#
# CF Train, N2 Test
# Accuracy: 0.6532, Balanced Accuracy: 0.4353
# Macro Precision: 0.7306, Macro Recall: 0.4353, Macro F1 Score: 0.4149
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.65      0.99      0.79     81128
#    DoS GoldenEye       0.91      0.04      0.07      1979
#         DoS Hulk       0.73      0.00      0.00     39670
# DoS Slowhttptest       0.82      0.52      0.64       926
#    DoS Slowloris       0.53      0.63      0.58      1421
#
#         accuracy                           0.65    125124
#        macro avg       0.73      0.44      0.41    125124
#     weighted avg       0.68      0.65      0.52    125124
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    290145       119229       170916
#                                                     DoS GoldenEye         7568       3390     11537.56       106793
#                                                     DoS Hulk            158559          0       694.19       128843
#                                                     DoS Slowhttptest      2419          0     14639.54       167903
#                                                     DoS Slowloris         2370          0     80446.31       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_3     290145       119229       170916
#                                                     DoS GoldenEye         7568          0       204.30        58333
#                                                     DoS Hulk            158559          0       528.67        64257
#                                                     DoS Slowhttptest      2419          0      3055.00        43264
#                                                     DoS Slowloris         2370          0      3403.97        57769
# CF Train, CF Test
# Accuracy: 0.9999, Balanced Accuracy: 0.9981
# Macro Precision: 0.9994, Macro Recall: 0.9981, Macro F1 Score: 0.9988
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     29808
#    DoS GoldenEye       1.00      1.00      1.00      1892
#         DoS Hulk       1.00      1.00      1.00     39640
# DoS Slowhttptest       1.00      1.00      1.00       605
#    DoS Slowloris       1.00      0.99      1.00       592
#
#         accuracy                           1.00     72537
#        macro avg       1.00      1.00      1.00     72537
#     weighted avg       1.00      1.00      1.00     72537
#
#
# N3 Train, N3 Test
# Accuracy: 0.9451, Balanced Accuracy: 0.5135
# Macro Precision: 0.7166, Macro Recall: 0.5135, Macro F1 Score: 0.5544
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.96      0.98      0.97     29808
#    DoS GoldenEye       0.30      0.00      0.00      1892
#         DoS Hulk       0.94      0.98      0.96     39640
# DoS Slowhttptest       0.99      0.43      0.60       605
#    DoS Slowloris       0.39      0.17      0.23       592
#
#         accuracy                           0.95     72537
#        macro avg       0.72      0.51      0.55     72537
#     weighted avg       0.93      0.95      0.93     72537
#
#
# CF Train, N3 Test
# Accuracy: 0.4150, Balanced Accuracy: 0.2974
# Macro Precision: 0.5639, Macro Recall: 0.2974, Macro F1 Score: 0.2568
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.41      1.00      0.58     29808
#    DoS GoldenEye       0.00      0.00      0.00      1892
#         DoS Hulk       1.00      0.00      0.00     39640
# DoS Slowhttptest       1.00      0.43      0.60       605
#    DoS Slowloris       0.41      0.05      0.10       592
#
#         accuracy                           0.42     72537
#        macro avg       0.56      0.30      0.26     72537
#     weighted avg       0.73      0.42      0.25     72537
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    271751       101923       169828
#                                                     DoS GoldenEye         7567       3390     11531.37       106793
#                                                     DoS Hulk            158557          0       693.43       128843
#                                                     DoS Slowhttptest      1469          0     19944.93       167903
#                                                     DoS Slowloris         2235          0     82604.02       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_4     271751       101923       169828
#                                                     DoS GoldenEye         7567          0       233.50        48079
#                                                     DoS Hulk            158557          0       529.51        65721
#                                                     DoS Slowhttptest      1469          0      1415.11        98560
#                                                     DoS Slowloris         2235          0       908.58         3004
# CF Train, CF Test
# Accuracy: 0.9999, Balanced Accuracy: 0.9984
# Macro Precision: 0.9988, Macro Recall: 0.9984, Macro F1 Score: 0.9986
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     25481
#    DoS GoldenEye       1.00      1.00      1.00      1892
#         DoS Hulk       1.00      1.00      1.00     39639
# DoS Slowhttptest       0.99      0.99      0.99       367
#    DoS Slowloris       1.00      1.00      1.00       559
#
#         accuracy                           1.00     67938
#        macro avg       1.00      1.00      1.00     67938
#     weighted avg       1.00      1.00      1.00     67938
#
#
# N4 Train, N4 Test
# Accuracy: 0.9789, Balanced Accuracy: 0.8208
# Macro Precision: 0.8859, Macro Recall: 0.8208, Macro F1 Score: 0.8493
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      0.99      1.00     25481
#    DoS GoldenEye       0.85      0.62      0.72      1892
#         DoS Hulk       0.98      0.99      0.98     39639
# DoS Slowhttptest       0.82      0.79      0.80       367
#    DoS Slowloris       0.78      0.71      0.74       559
#
#         accuracy                           0.98     67938
#        macro avg       0.89      0.82      0.85     67938
#     weighted avg       0.98      0.98      0.98     67938
#
#
# CF Train, N4 Test
# Accuracy: 0.3756, Balanced Accuracy: 0.2151
# Macro Precision: 0.4597, Macro Recall: 0.2151, Macro F1 Score: 0.1382
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.38      1.00      0.55     25481
#    DoS GoldenEye       0.00      0.00      0.00      1892
#         DoS Hulk       0.00      0.00      0.00     39639
# DoS Slowhttptest       0.92      0.03      0.06       367
#    DoS Slowloris       1.00      0.04      0.08       559
#
#         accuracy                           0.38     67938
#        macro avg       0.46      0.22      0.14     67938
#     weighted avg       0.15      0.38      0.21     67938
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    263319       93547        169772
#                                                     DoS GoldenEye         7567       3390     11531.37       106793
#                                                     DoS Hulk            158557          0       693.43       128843
#                                                     DoS Slowhttptest      1413          5     20661.07       167903
#                                                     DoS Slowloris         2235          0     82604.02       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_5     263319       93547        169772
#                                                     DoS GoldenEye         7567          0       255.96        48080
#                                                     DoS Hulk            158557          0       552.16        65721
#                                                     DoS Slowhttptest      1413          1      2068.20        15036
#                                                     DoS Slowloris         2235          0       989.58         3005
# CF Train, CF Test
# Accuracy: 0.9998, Balanced Accuracy: 0.9984
# Macro Precision: 0.9999, Macro Recall: 0.9984, Macro F1 Score: 0.9992
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     23387
#    DoS GoldenEye       1.00      1.00      1.00      1892
#         DoS Hulk       1.00      1.00      1.00     39639
# DoS Slowhttptest       1.00      1.00      1.00       353
#    DoS Slowloris       1.00      1.00      1.00       559
#
#         accuracy                           1.00     65830
#        macro avg       1.00      1.00      1.00     65830
#     weighted avg       1.00      1.00      1.00     65830
#
#
# N5 Train, N5 Test
# Accuracy: 0.9844, Balanced Accuracy: 0.8763
# Macro Precision: 0.9134, Macro Recall: 0.8763, Macro F1 Score: 0.8922
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     23387
#    DoS GoldenEye       0.84      0.68      0.75      1892
#         DoS Hulk       0.98      0.99      0.99     39639
# DoS Slowhttptest       0.90      0.78      0.84       353
#    DoS Slowloris       0.85      0.92      0.88       559
#
#         accuracy                           0.98     65830
#        macro avg       0.91      0.88      0.89     65830
#     weighted avg       0.98      0.98      0.98     65830
#
#
# CF Train, N5 Test
# Accuracy: 0.3381, Balanced Accuracy: 0.3185
# Macro Precision: 0.1279, Macro Recall: 0.3185, Macro F1 Score: 0.1636
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.56      0.94      0.70     23387
#    DoS GoldenEye       0.00      0.00      0.00      1892
#         DoS Hulk       0.00      0.00      0.00     39639
# DoS Slowhttptest       0.01      0.48      0.01       353
#    DoS Slowloris       0.07      0.17      0.10       559
#
#         accuracy                           0.34     65830
#        macro avg       0.13      0.32      0.16     65830
#     weighted avg       0.20      0.34      0.25     65830
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    261477       92476        169001
#                                                     DoS GoldenEye         7567       3390     11531.37       106793
#                                                     DoS Hulk            158557          0       693.43       128843
#                                                     DoS Slowhttptest       679         11     42988.86       167903
#                                                     DoS Slowloris         2198          2     83994.51       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_6     261477       92476        169001
#                                                     DoS GoldenEye         7567          0      4773.53        52865
#                                                     DoS Hulk            158557          0       637.06        66719
#                                                     DoS Slowhttptest       679          8      6174.75        31079
#                                                     DoS Slowloris         2198          1      2466.67        53080
# CF Train, CF Test
# Accuracy: 0.9999, Balanced Accuracy: 0.9959
# Macro Precision: 0.9991, Macro Recall: 0.9959, Macro F1 Score: 0.9975
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     23119
#    DoS GoldenEye       1.00      1.00      1.00      1892
#         DoS Hulk       1.00      1.00      1.00     39640
# DoS Slowhttptest       1.00      0.98      0.99       170
#    DoS Slowloris       1.00      1.00      1.00       549
#
#         accuracy                           1.00     65370
#        macro avg       1.00      1.00      1.00     65370
#     weighted avg       1.00      1.00      1.00     65370
#
#
# N6 Train, N6 Test
# Accuracy: 0.9959, Balanced Accuracy: 0.9612
# Macro Precision: 0.9804, Macro Recall: 0.9612, Macro F1 Score: 0.9705
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     23119
#    DoS GoldenEye       0.96      0.91      0.93      1892
#         DoS Hulk       1.00      1.00      1.00     39640
# DoS Slowhttptest       0.94      0.91      0.92       170
#    DoS Slowloris       1.00      1.00      1.00       549
#
#         accuracy                           1.00     65370
#        macro avg       0.98      0.96      0.97     65370
#     weighted avg       1.00      1.00      1.00     65370
#
#
# CF Train, N6 Test
# Accuracy: 0.4653, Balanced Accuracy: 0.6168
# Macro Precision: 0.6010, Macro Recall: 0.6168, Macro F1 Score: 0.4620
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.43      1.00      0.60     23119
#    DoS GoldenEye       1.00      0.54      0.70      1892
#         DoS Hulk       0.99      0.14      0.25     39640
# DoS Slowhttptest       0.02      0.40      0.03       170
#    DoS Slowloris       0.56      1.00      0.72       549
#
#         accuracy                           0.47     65370
#        macro avg       0.60      0.62      0.46     65370
#     weighted avg       0.79      0.47      0.39     65370
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    260091       91375        168716
#                                                     DoS GoldenEye         7567       3390     11531.37       106793
#                                                     DoS Hulk            158461          0       693.84       128843
#                                                     DoS Slowhttptest       631         11     46177.99       167903
#                                                     DoS Slowloris         2057          2     89714.56       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_7     260091       91375        168716
#                                                     DoS GoldenEye         7567          0      5415.78        63095
#                                                     DoS Hulk            158461          0       659.39        66719
#                                                     DoS Slowhttptest       631          9      8649.36        63160
#                                                     DoS Slowloris         2057          2      3017.98        54078
# CF Train, CF Test
# Accuracy: 0.9999, Balanced Accuracy: 0.9989
# Macro Precision: 0.9961, Macro Recall: 0.9989, Macro F1 Score: 0.9975
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     22844
#    DoS GoldenEye       1.00      1.00      1.00      1892
#         DoS Hulk       1.00      1.00      1.00     39615
# DoS Slowhttptest       0.98      1.00      0.99       158
#    DoS Slowloris       1.00      1.00      1.00       514
#
#         accuracy                           1.00     65023
#        macro avg       1.00      1.00      1.00     65023
#     weighted avg       1.00      1.00      1.00     65023
#
#
# N7 Train, N7 Test
# Accuracy: 0.9980, Balanced Accuracy: 0.9887
# Macro Precision: 0.9832, Macro Recall: 0.9887, Macro F1 Score: 0.9858
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     22844
#    DoS GoldenEye       0.98      0.96      0.97      1892
#         DoS Hulk       1.00      1.00      1.00     39615
# DoS Slowhttptest       0.94      0.99      0.97       158
#    DoS Slowloris       1.00      0.99      1.00       514
#
#         accuracy                           1.00     65023
#        macro avg       0.98      0.99      0.99     65023
#     weighted avg       1.00      1.00      1.00     65023
#
#
# CF Train, N7 Test
# Accuracy: 0.7865, Balanced Accuracy: 0.8326
# Macro Precision: 0.6971, Macro Recall: 0.8326, Macro F1 Score: 0.6875
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.65      1.00      0.79     22844
#    DoS GoldenEye       1.00      0.74      0.85      1892
#         DoS Hulk       0.99      0.66      0.80     39615
# DoS Slowhttptest       0.08      0.78      0.15       158
#    DoS Slowloris       0.76      0.98      0.86       514
#
#         accuracy                           0.79     65023
#        macro avg       0.70      0.83      0.69     65023
#     weighted avg       0.87      0.79      0.79     65023
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    251718       87891        163827
#                                                     DoS GoldenEye         7567       3390     11531.37       106793
#                                                     DoS Hulk            153941          0       711.84       128843
#                                                     DoS Slowhttptest       458         11     62491.69       167903
#                                                     DoS Slowloris         1861        798     97613.68       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_8     251718       87891        163827
#                                                     DoS GoldenEye         7567          1      5743.47        63095
#                                                     DoS Hulk            153941          0       688.26        68723
#                                                     DoS Slowhttptest       458         11     11213.53        63160
#                                                     DoS Slowloris         1861          3      2364.51        54079
# CF Train, CF Test
# Accuracy: 0.9999, Balanced Accuracy: 0.9955
# Macro Precision: 0.9964, Macro Recall: 0.9955, Macro F1 Score: 0.9959
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     21973
#    DoS GoldenEye       1.00      1.00      1.00      1892
#         DoS Hulk       1.00      1.00      1.00     38486
# DoS Slowhttptest       0.98      0.98      0.98       114
#    DoS Slowloris       1.00      1.00      1.00       465
#
#         accuracy                           1.00     62930
#        macro avg       1.00      1.00      1.00     62930
#     weighted avg       1.00      1.00      1.00     62930
#
#
# N8 Train, N8 Test
# Accuracy: 0.9992, Balanced Accuracy: 0.9896
# Macro Precision: 0.9920, Macro Recall: 0.9896, Macro F1 Score: 0.9908
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     21973
#    DoS GoldenEye       0.99      0.98      0.99      1892
#         DoS Hulk       1.00      1.00      1.00     38486
# DoS Slowhttptest       0.97      0.97      0.97       114
#    DoS Slowloris       0.99      0.99      0.99       465
#
#         accuracy                           1.00     62930
#        macro avg       0.99      0.99      0.99     62930
#     weighted avg       1.00      1.00      1.00     62930
#
#
# CF Train, N8 Test
# Accuracy: 0.9351, Balanced Accuracy: 0.9119
# Macro Precision: 0.7052, Macro Recall: 0.9119, Macro F1 Score: 0.7388
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.88      1.00      0.94     21973
#    DoS GoldenEye       1.00      0.78      0.88      1892
#         DoS Hulk       0.99      0.91      0.95     38486
# DoS Slowhttptest       0.17      0.88      0.28       114
#    DoS Slowloris       0.48      1.00      0.65       465
#
#         accuracy                           0.94     62930
#        macro avg       0.71      0.91      0.74     62930
#     weighted avg       0.95      0.94      0.94     62930
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    222951       85492        137459
#                                                     DoS GoldenEye         7411       3390     11559.76       106793
#                                                     DoS Hulk            127790          0       806.45       128843
#                                                     DoS Slowhttptest       415         17     68332.80       167903
#                                                     DoS Slowloris         1843       2001     98386.76       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_9     222951       85492        137459
#                                                     DoS GoldenEye         7411          1      6757.70        63095
#                                                     DoS Hulk            127790          0       784.01        68723
#                                                     DoS Slowhttptest       415         17     12643.28        63161
#                                                     DoS Slowloris         1843          3      3583.45        59080
# CF Train, CF Test
# Accuracy: 0.9999, Balanced Accuracy: 0.9973
# Macro Precision: 0.9961, Macro Recall: 0.9973, Macro F1 Score: 0.9967
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     21373
#    DoS GoldenEye       1.00      1.00      1.00      1853
#         DoS Hulk       1.00      1.00      1.00     31947
# DoS Slowhttptest       0.98      0.99      0.99       104
#    DoS Slowloris       1.00      1.00      1.00       461
#
#         accuracy                           1.00     55738
#        macro avg       1.00      1.00      1.00     55738
#     weighted avg       1.00      1.00      1.00     55738
#
#
# N9 Train, N9 Test
# Accuracy: 0.9996, Balanced Accuracy: 0.9941
# Macro Precision: 0.9861, Macro Recall: 0.9941, Macro F1 Score: 0.9900
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     21373
#    DoS GoldenEye       1.00      0.99      1.00      1853
#         DoS Hulk       1.00      1.00      1.00     31947
# DoS Slowhttptest       0.94      0.98      0.96       104
#    DoS Slowloris       1.00      1.00      1.00       461
#
#         accuracy                           1.00     55738
#        macro avg       0.99      0.99      0.99     55738
#     weighted avg       1.00      1.00      1.00     55738
#
#
# CF Train, N9 Test
# Accuracy: 0.9670, Balanced Accuracy: 0.8133
# Macro Precision: 0.7879, Macro Recall: 0.8133, Macro F1 Score: 0.7497
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.95      1.00      0.98     21373
#    DoS GoldenEye       1.00      0.82      0.90      1853
#         DoS Hulk       0.99      0.96      0.98     31947
# DoS Slowhttptest       0.11      0.70      0.19       104
#    DoS Slowloris       0.88      0.58      0.70       461
#
#         accuracy                           0.97     55738
#        macro avg       0.79      0.81      0.75     55738
#     weighted avg       0.98      0.97      0.97     55738
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    141273       84555        56718
#                                                     DoS GoldenEye         6183       3390     11719.40       106793
#                                                     DoS Hulk             48451          1      1657.54       128843
#                                                     DoS Slowhttptest       246       2603    113119.01       167903
#                                                     DoS Slowloris         1838       2001     98596.24       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_10    141273       84555        56718
#                                                     DoS GoldenEye         6183          1      6603.48        63096
#                                                     DoS Hulk             48451          1      1602.42        72731
#                                                     DoS Slowhttptest       246       2603     20056.63        63161
#                                                     DoS Slowloris         1838         21      5688.29        59080
# CF Train, CF Test
# Accuracy: 0.9997, Balanced Accuracy: 0.9860
# Macro Precision: 0.9919, Macro Recall: 0.9860, Macro F1 Score: 0.9889
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     21139
#    DoS GoldenEye       1.00      1.00      1.00      1546
#         DoS Hulk       1.00      1.00      1.00     12113
# DoS Slowhttptest       0.97      0.93      0.95        61
#    DoS Slowloris       0.99      1.00      1.00       460
#
#         accuracy                           1.00     35319
#        macro avg       0.99      0.99      0.99     35319
#     weighted avg       1.00      1.00      1.00     35319
#
#
# N10 Train, N10 Test
# Accuracy: 0.9997, Balanced Accuracy: 0.9919
# Macro Precision: 0.9927, Macro Recall: 0.9919, Macro F1 Score: 0.9923
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     21139
#    DoS GoldenEye       1.00      1.00      1.00      1546
#         DoS Hulk       1.00      1.00      1.00     12113
# DoS Slowhttptest       0.97      0.97      0.97        61
#    DoS Slowloris       1.00      1.00      1.00       460
#
#         accuracy                           1.00     35319
#        macro avg       0.99      0.99      0.99     35319
#     weighted avg       1.00      1.00      1.00     35319
#
#
# CF Train, N10 Test
# Accuracy: 0.9775, Balanced Accuracy: 0.8062
# Macro Precision: 0.8076, Macro Recall: 0.8062, Macro F1 Score: 0.8046
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.98      1.00      0.99     21139
#    DoS GoldenEye       1.00      0.84      0.92      1546
#         DoS Hulk       0.98      0.96      0.97     12113
# DoS Slowhttptest       0.19      0.23      0.21        61
#    DoS Slowloris       0.89      1.00      0.94       460
#
#         accuracy                           0.98     35319
#        macro avg       0.81      0.81      0.80     35319
#     weighted avg       0.98      0.98      0.98     35319
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    102837       82489        20348
#                                                     DoS GoldenEye         5585       3390     11790.60       106793
#                                                     DoS Hulk             12706          2      2994.24       128843
#                                                     DoS Slowhttptest       239       4266    116337.75       167903
#                                                     DoS Slowloris         1818       4968     99350.11       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_11    102837       82489        20348
#                                                     DoS GoldenEye         5585          2      6550.69        63096
#                                                     DoS Hulk             12706          2      2787.30        72731
#                                                     DoS Slowhttptest       239       2655     22290.57        63364
#                                                     DoS Slowloris         1818         22      9709.68        50039
# CF Train, CF Test
# Accuracy: 0.9998, Balanced Accuracy: 0.9990
# Macro Precision: 0.9999, Macro Recall: 0.9990, Macro F1 Score: 0.9995
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     20623
#    DoS GoldenEye       1.00      1.00      1.00      1396
#         DoS Hulk       1.00      1.00      1.00      3177
# DoS Slowhttptest       1.00      1.00      1.00        60
#    DoS Slowloris       1.00      1.00      1.00       454
#
#         accuracy                           1.00     25710
#        macro avg       1.00      1.00      1.00     25710
#     weighted avg       1.00      1.00      1.00     25710
#
#
# N11 Train, N11 Test
# Accuracy: 0.9996, Balanced Accuracy: 0.9955
# Macro Precision: 0.9995, Macro Recall: 0.9955, Macro F1 Score: 0.9975
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     20623
#    DoS GoldenEye       1.00      1.00      1.00      1396
#         DoS Hulk       1.00      1.00      1.00      3177
# DoS Slowhttptest       1.00      0.98      0.99        60
#    DoS Slowloris       1.00      1.00      1.00       454
#
#         accuracy                           1.00     25710
#        macro avg       1.00      1.00      1.00     25710
#     weighted avg       1.00      1.00      1.00     25710
#
#
# CF Train, N11 Test
# Accuracy: 0.9834, Balanced Accuracy: 0.8232
# Macro Precision: 0.8674, Macro Recall: 0.8232, Macro F1 Score: 0.8418
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       0.99      1.00      1.00     20623
#    DoS GoldenEye       1.00      0.83      0.91      1396
#         DoS Hulk       0.94      0.95      0.95      3177
# DoS Slowhttptest       0.45      0.33      0.38        60
#    DoS Slowloris       0.95      1.00      0.97       454
#
#         accuracy                           0.98     25710
#        macro avg       0.87      0.82      0.84     25710
#     weighted avg       0.98      0.98      0.98     25710
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    91649        80104        11545
#                                                     DoS GoldenEye         5253       3390     11810.10       106793
#                                                     DoS Hulk              4245         10      3567.53       128843
#                                                     DoS Slowhttptest       236       7619    117744.13       167903
#                                                     DoS Slowloris         1811       5024     99678.52       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_12    91649        80104        11545
#                                                     DoS GoldenEye         5253          2      7293.73        68586
#                                                     DoS Hulk              4245         10      2991.83        80753
#                                                     DoS Slowhttptest       236       7619     25932.32        63568
#                                                     DoS Slowloris         1811         22     18236.57        25680
# CF Train, CF Test
# Accuracy: 0.9996, Balanced Accuracy: 0.9915
# Macro Precision: 0.9998, Macro Recall: 0.9915, Macro F1 Score: 0.9956
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     20027
#    DoS GoldenEye       1.00      1.00      1.00      1313
#         DoS Hulk       1.00      1.00      1.00      1061
# DoS Slowhttptest       1.00      0.97      0.98        59
#    DoS Slowloris       1.00      1.00      1.00       453
#
#         accuracy                           1.00     22913
#        macro avg       1.00      0.99      1.00     22913
#     weighted avg       1.00      1.00      1.00     22913
#
#
# N12 Train, N12 Test
# Accuracy: 0.9995, Balanced Accuracy: 0.9913
# Macro Precision: 0.9954, Macro Recall: 0.9913, Macro F1 Score: 0.9933
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     20027
#    DoS GoldenEye       1.00      0.99      1.00      1313
#         DoS Hulk       1.00      1.00      1.00      1061
# DoS Slowhttptest       0.98      0.97      0.97        59
#    DoS Slowloris       1.00      1.00      1.00       453
#
#         accuracy                           1.00     22913
#        macro avg       1.00      0.99      0.99     22913
#     weighted avg       1.00      1.00      1.00     22913
#
#
# CF Train, N12 Test
# Accuracy: 0.9880, Balanced Accuracy: 0.8185
# Macro Precision: 0.8905, Macro Recall: 0.8185, Macro F1 Score: 0.8378
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     20027
#    DoS GoldenEye       1.00      0.86      0.92      1313
#         DoS Hulk       0.87      0.97      0.91      1061
# DoS Slowhttptest       0.64      0.27      0.38        59
#    DoS Slowloris       0.95      1.00      0.97       453
#
#         accuracy                           0.99     22913
#        macro avg       0.89      0.82      0.84     22913
#     weighted avg       0.99      0.99      0.99     22913
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    83175        75062         8113
#                                                     DoS GoldenEye         4366       3390     11941.64       106793
#                                                     DoS Hulk              1716         10      5764.71       128843
#                                                     DoS Slowhttptest       234      18112    118635.40       167903
#                                                     DoS Slowloris         1797       5024    100324.47       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_13    83175        75062         8113
#                                                     DoS GoldenEye         4366          2      8688.62        68586
#                                                     DoS Hulk              1716         10      4343.46        80754
#                                                     DoS Slowhttptest       234      13088     29969.69        63976
#                                                     DoS Slowloris         1797         22     25719.71        31622
# CF Train, CF Test
# Accuracy: 0.9998, Balanced Accuracy: 0.9986
# Macro Precision: 0.9931, Macro Recall: 0.9986, Macro F1 Score: 0.9958
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     18766
#    DoS GoldenEye       1.00      1.00      1.00      1092
#         DoS Hulk       1.00      1.00      1.00       429
# DoS Slowhttptest       0.97      1.00      0.98        58
#    DoS Slowloris       1.00      1.00      1.00       449
#
#         accuracy                           1.00     20794
#        macro avg       0.99      1.00      1.00     20794
#     weighted avg       1.00      1.00      1.00     20794
#
#
# N13 Train, N13 Test
# Accuracy: 0.9994, Balanced Accuracy: 0.9969
# Macro Precision: 0.9985, Macro Recall: 0.9969, Macro F1 Score: 0.9977
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     18766
#    DoS GoldenEye       1.00      0.99      1.00      1092
#         DoS Hulk       1.00      1.00      1.00       429
# DoS Slowhttptest       1.00      1.00      1.00        58
#    DoS Slowloris       1.00      1.00      1.00       449
#
#         accuracy                           1.00     20794
#        macro avg       1.00      1.00      1.00     20794
#     weighted avg       1.00      1.00      1.00     20794
#
#
# CF Train, N13 Test
# Accuracy: 0.9903, Balanced Accuracy: 0.7924
# Macro Precision: 0.8745, Macro Recall: 0.7924, Macro F1 Score: 0.7894
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     18766
#    DoS GoldenEye       1.00      0.89      0.94      1092
#         DoS Hulk       0.79      0.98      0.87       429
# DoS Slowhttptest       0.67      0.10      0.18        58
#    DoS Slowloris       0.92      1.00      0.96       449
#
#         accuracy                           0.99     20794
#        macro avg       0.87      0.79      0.79     20794
#     weighted avg       0.99      0.99      0.99     20794
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    75628        70410         5218
#                                                     DoS GoldenEye         2560       3390     12578.05       106793
#                                                     DoS Hulk               642        161     11166.31       128843
#                                                     DoS Slowhttptest       234      18112    118635.40       167903
#                                                     DoS Slowloris         1782       5024    101004.00       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_14    75628        70410         5218
#                                                     DoS GoldenEye         2560          3      9709.52        68586
#                                                     DoS Hulk               642        161      8026.42        96779
#                                                     DoS Slowhttptest       234      13088     33832.93        64792
#                                                     DoS Slowloris         1782        212     30787.90        32624
# CF Train, CF Test
# Accuracy: 0.9995, Balanced Accuracy: 0.9874
# Macro Precision: 0.9955, Macro Recall: 0.9874, Macro F1 Score: 0.9914
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     17603
#    DoS GoldenEye       1.00      1.00      1.00       640
#         DoS Hulk       1.00      1.00      1.00       160
# DoS Slowhttptest       0.98      0.95      0.97        59
#    DoS Slowloris       1.00      0.99      1.00       445
#
#         accuracy                           1.00     18907
#        macro avg       1.00      0.99      0.99     18907
#     weighted avg       1.00      1.00      1.00     18907
#
#
# N14 Train, N14 Test
# Accuracy: 0.9995, Balanced Accuracy: 0.9897
# Macro Precision: 0.9913, Macro Recall: 0.9897, Macro F1 Score: 0.9905
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     17603
#    DoS GoldenEye       1.00      1.00      1.00       640
#         DoS Hulk       0.99      0.99      0.99       160
# DoS Slowhttptest       0.97      0.97      0.97        59
#    DoS Slowloris       1.00      0.99      1.00       445
#
#         accuracy                           1.00     18907
#        macro avg       0.99      0.99      0.99     18907
#     weighted avg       1.00      1.00      1.00     18907
#
#
# CF Train, N14 Test
# Accuracy: 0.9940, Balanced Accuracy: 0.8355
# Macro Precision: 0.9218, Macro Recall: 0.8355, Macro F1 Score: 0.8425
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     17603
#    DoS GoldenEye       0.99      0.91      0.95       640
#         DoS Hulk       0.76      0.97      0.85       160
# DoS Slowhttptest       0.95      0.31      0.46        59
#    DoS Slowloris       0.91      0.99      0.95       445
#
#         accuracy                           0.99     18907
#        macro avg       0.92      0.84      0.84     18907
#     weighted avg       0.99      0.99      0.99     18907
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    69081        65645         3436
#                                                     DoS GoldenEye         1246       4407     14582.65       106793
#                                                     DoS Hulk               181        161     29506.91       128843
#                                                     DoS Slowhttptest       234      18112    118635.40       167903
#                                                     DoS Slowloris         1775       5240    101325.16       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_15    69081        65645         3436
#                                                     DoS GoldenEye         1246          5     11117.28        68587
#                                                     DoS Hulk               181        161     18406.82        96779
#                                                     DoS Slowhttptest       234      13089     41071.45        66428
#                                                     DoS Slowloris         1775        222     42131.41        51365
# CF Train, CF Test
# Accuracy: 0.9995, Balanced Accuracy: 0.9880
# Macro Precision: 0.9965, Macro Recall: 0.9880, Macro F1 Score: 0.9922
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     16412
#    DoS GoldenEye       1.00      0.98      0.99       312
#         DoS Hulk       1.00      0.98      0.99        45
# DoS Slowhttptest       0.98      0.98      0.98        58
#    DoS Slowloris       1.00      1.00      1.00       444
#
#         accuracy                           1.00     17271
#        macro avg       1.00      0.99      0.99     17271
#     weighted avg       1.00      1.00      1.00     17271
#
#
# N15 Train, N15 Test
# Accuracy: 0.9994, Balanced Accuracy: 0.9842
# Macro Precision: 0.9919, Macro Recall: 0.9842, Macro F1 Score: 0.9879
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     16412
#    DoS GoldenEye       0.99      0.99      0.99       312
#         DoS Hulk       1.00      0.96      0.98        45
# DoS Slowhttptest       0.97      0.98      0.97        58
#    DoS Slowloris       1.00      1.00      1.00       444
#
#         accuracy                           1.00     17271
#        macro avg       0.99      0.98      0.99     17271
#     weighted avg       1.00      1.00      1.00     17271
#
#
# CF Train, N15 Test
# Accuracy: 0.9949, Balanced Accuracy: 0.8216
# Macro Precision: 0.8480, Macro Recall: 0.8216, Macro F1 Score: 0.8104
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     16412
#    DoS GoldenEye       1.00      0.88      0.94       312
#         DoS Hulk       0.61      0.96      0.75        45
# DoS Slowhttptest       0.67      0.28      0.39        58
#    DoS Slowloris       0.97      1.00      0.98       444
#
#         accuracy                           0.99     17271
#        macro avg       0.85      0.82      0.81     17271
#     weighted avg       0.99      0.99      0.99     17271
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    64929        62137         2792
#                                                     DoS GoldenEye          743       4408     17014.65       106793
#                                                     DoS Hulk                61       1709     77593.98       128843
#                                                     DoS Slowhttptest       234      18112    118635.40       167903
#                                                     DoS Slowloris         1754       5240    102052.64       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_16    64929        62137         2792
#                                                     DoS GoldenEye          743         10     13591.32       106793
#                                                     DoS Hulk                61       1612     57281.75       128842
#                                                     DoS Slowhttptest       234      13110     55096.79       107103
#                                                     DoS Slowloris         1754        222     70441.35       102735
# CF Train, CF Test
# Accuracy: 0.9995, Balanced Accuracy: 0.9774
# Macro Precision: 0.9888, Macro Recall: 0.9774, Macro F1 Score: 0.9828
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     15535
#    DoS GoldenEye       0.99      0.97      0.98       186
#         DoS Hulk       1.00      0.93      0.97        15
# DoS Slowhttptest       0.95      0.98      0.97        58
#    DoS Slowloris       1.00      1.00      1.00       439
#
#         accuracy                           1.00     16233
#        macro avg       0.99      0.98      0.98     16233
#     weighted avg       1.00      1.00      1.00     16233
#
#
# N16 Train, N16 Test
# Accuracy: 0.9994, Balanced Accuracy: 0.9763
# Macro Precision: 0.9877, Macro Recall: 0.9763, Macro F1 Score: 0.9817
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     15535
#    DoS GoldenEye       0.99      0.97      0.98       186
#         DoS Hulk       1.00      0.93      0.97        15
# DoS Slowhttptest       0.95      0.98      0.97        58
#    DoS Slowloris       1.00      1.00      1.00       439
#
#         accuracy                           1.00     16233
#        macro avg       0.99      0.98      0.98     16233
#     weighted avg       1.00      1.00      1.00     16233
#
#
# CF Train, N16 Test
# Accuracy: 0.9972, Balanced Accuracy: 0.8449
# Macro Precision: 0.9087, Macro Recall: 0.8449, Macro F1 Score: 0.8702
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     15535
#    DoS GoldenEye       0.99      0.92      0.96       186
#         DoS Hulk       0.69      0.73      0.71        15
# DoS Slowhttptest       0.87      0.57      0.69        58
#    DoS Slowloris       1.00      1.00      1.00       439
#
#         accuracy                           1.00     16233
#        macro avg       0.91      0.84      0.87     16233
#     weighted avg       1.00      1.00      1.00     16233
#      DS         TOTAL        BENIGN      ANOMALY        Anomaly breakdown       Min Dur.   Mean Dur.     Max Dur.
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_cf    61237        58779         2458
#                                                     DoS GoldenEye          487       4408     19857.99       106793
#                                                     DoS Hulk                43       3341    104645.21       128843
#                                                     DoS Slowhttptest       234      18112    118635.40       167903
#                                                     DoS Slowloris         1694       5240    103080.76       105745
# ------------ ------------ ------------ ------------ -------------------------- ---------- ------------ ------------
# wednesday_17    61237        58779         2458
#                                                     DoS GoldenEye          487         12     16609.48       106793
#                                                     DoS Hulk                43       1612     77516.74       128843
#                                                     DoS Slowhttptest       234      13110     67436.24       107773
#                                                     DoS Slowloris         1694        235     87924.51       103735
# CF Train, CF Test
# Accuracy: 0.9997, Balanced Accuracy: 0.9898
# Macro Precision: 0.9914, Macro Recall: 0.9898, Macro F1 Score: 0.9906
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     14695
#    DoS GoldenEye       0.99      0.98      0.99       122
#         DoS Hulk       1.00      1.00      1.00        11
# DoS Slowhttptest       0.97      0.97      0.97        58
#    DoS Slowloris       1.00      1.00      1.00       424
#
#         accuracy                           1.00     15310
#        macro avg       0.99      0.99      0.99     15310
#     weighted avg       1.00      1.00      1.00     15310
#
#
# N17 Train, N17 Test
# Accuracy: 0.9996, Balanced Accuracy: 0.9865
# Macro Precision: 0.9833, Macro Recall: 0.9865, Macro F1 Score: 0.9849
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     14695
#    DoS GoldenEye       0.98      0.97      0.98       122
#         DoS Hulk       1.00      1.00      1.00        11
# DoS Slowhttptest       0.93      0.97      0.95        58
#    DoS Slowloris       1.00      1.00      1.00       424
#
#         accuracy                           1.00     15310
#        macro avg       0.98      0.99      0.98     15310
#     weighted avg       1.00      1.00      1.00     15310
#
#
# CF Train, N17 Test
# Accuracy: 0.9978, Balanced Accuracy: 0.8537
# Macro Precision: 0.9437, Macro Recall: 0.8537, Macro F1 Score: 0.8924
# Classification Report:
#                   precision    recall  f1-score   support
#
#           BENIGN       1.00      1.00      1.00     14695
#    DoS GoldenEye       0.96      0.94      0.95       122
#         DoS Hulk       0.88      0.64      0.74        11
# DoS Slowhttptest       0.89      0.69      0.78        58
#    DoS Slowloris       1.00      1.00      1.00       424
#
#         accuracy                           1.00     15310
#        macro avg       0.94      0.85      0.89     15310
#     weighted avg       1.00      1.00      1.00     15310
